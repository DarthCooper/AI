# %%
import pandas as pd
import math
import seaborn as sns
import matplotlib.pyplot as plt
from utils.KeyMethods import KeyMethods

# %%
df = pd.read_json("games.json")

# %%
sns.scatterplot(data=df, x="price_final", y="positive_ratio")
# Out:
# <AxesSubplot:xlabel='price_final', ylabel='positive_ratio'>

# %%
df_filtered = KeyMethods.RemoveOutliers(df, "price_final")

sns.scatterplot(data=df_filtered, x="price_final", y="positive_ratio")
# Out:
# <AxesSubplot:xlabel='price_final', ylabel='positive_ratio'>

# %%
KeyMethods.calcCorr(df, 'positive_ratio', "user_reviews", "pearson")
# Out:
#                 positive_ratio  user_reviews
# positive_ratio        1.000000      0.123121
# user_reviews          0.123121      1.000000

# %%
df = pd.read_json("games.json")

sns.scatterplot(data = fixedDF, x = "positive_ratio", y = "user_reviews")
# Out:
# <AxesSubplot:xlabel='positive_ratio', ylabel='user_reviews'>

# %%
fixedX = KeyMethods.RemoveOutliers(df, "positive_ratio")
fixedDF = KeyMethods.RemoveOutliers(df, "user_reviews")

sns.scatterplot(data = fixedDF, x = "positive_ratio", y = "user_reviews")
# Out:
# <AxesSubplot:xlabel='positive_ratio', ylabel='user_reviews'>
