# %%
import pandas as pd
import math
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from utils.KeyMethods import KeyMethods

# %%
df = pd.read_json("tsla.json")

# %%
df.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'rsi_7', 'rsi_14',
#        'cci_7', 'cci_14', 'sma_50', 'ema_50', 'sma_100', 'ema_100', 'macd',
#        'bollinger', 'TrueRange', 'atr_7', 'atr_14', 'next_day_close'],
#       dtype='object')

# %%
sns.scatterplot(data = df, x = "volume", y = "high")
# Out:
# <AxesSubplot:xlabel='volume', ylabel='high'>

# %%
df['open'].corr(df['volume'])
# Out:
# -0.048496276906608585

# %%
KeyMethods.calcCorr(df, 'open', 'volume', 'pearson')
# Out:
#             open    volume
# open    1.000000  0.201772
# volume  0.201772  1.000000

# %%
fixedX = KeyMethods.RemoveOutliers(df, "volume")
fixedDF = KeyMethods.RemoveOutliers(df, "high")

log_high = np.log10(fixedDF['high'])

fixedDF["Log High"] = log_high

sns.scatterplot(data = fixedDF, x = "Log High", y = "volume")
# Out:
# C:\Users\lbarber\AppData\Local\Temp\ipykernel_22852\4179269575.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fixedDF["Log High"] = log_high
# <AxesSubplot:xlabel='Log High', ylabel='volume'>
